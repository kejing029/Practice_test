# %%
from time import sleep
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
from PIL import Image

# %%
URL="https://www.cxstar.com"
driver = webdriver.Chrome()
driver.implicitly_wait(5)
driver.get(URL)
driver.find_element_by_name("head$txttopsearch").clear()
driver.find_element_by_name("head$txttopsearch").send_keys("围城")
sleep(1)
driver.find_element_by_id('head_imgbtntopsearch').click()
driver.find_element_by_xpath('//a[@title="围城"]').click()
sleep(1)

element = driver.find_element_by_tag_name("canvas")
print(element.location)                # 打印元素坐标
print(element.size)                    # 打印元素大小

left = element.location['x']
top = element.location['y']
right = element.location['x'] + element.size['width']
bottom = element.location['y'] + element.size['height']

im = Image.open('bdbutton.png')
im = im.crop((left, top, right, bottom))
im.save('bdbutton.png')
# driver.find_element_by_class_name('detail-qrcodeimg').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-40-a452ffb7afa2> in <module>
#      10 sleep(1)
#      11
# ---> 12 element = driver.find_element_by_tag_name("canvas")
#      13 print(element.location)                # 打印元素坐标
#      14 print(element.size)                    # 打印元素大小
#
# c:\users\kejin\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_tag_name(self, name)
#     528             element = driver.find_element_by_tag_name('h1')
#     529         """
# --> 530         return self.find_element(by=By.TAG_NAME, value=name)
#     531
#     532     def find_elements_by_tag_name(self, name):
#
# c:\users\kejin\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
# ...

# %%
help(webdriver.Chrome())
# Out:
# Help on WebDriver in module selenium.webdriver.chrome.webdriver object:
#
# class WebDriver(selenium.webdriver.remote.webdriver.WebDriver)
#  |  WebDriver(executable_path='chromedriver', port=0, options=None, service_args=None, desired_capabilities=None, service_log_path=None, chrome_options=None, keep_alive=True)
#  |
#  |  Controls the ChromeDriver and allows you to drive the browser.
#  |
#  |  You will need to download the ChromeDriver executable from
#  |  http://chromedriver.storage.googleapis.com/index.html
#  |
#  |  Method resolution order:
#  |      WebDriver
#  |      selenium.webdriver.remote.webdriver.WebDriver
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, executable_path='chromedriver', port=0, options=None, service_args=None, desired_capabilities=None, service_log_path=None, chrome_options=None, keep_alive=True)
#  |      Creates a new instance of the chrome driver.
#  |
# ...
